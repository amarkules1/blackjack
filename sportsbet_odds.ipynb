# %%
import pandas as pd

# %%
# given american line odds, calculate implied percentage
def american_to_probability(odds):
    if odds > 0:
        return 100 / (odds + 100)
    else:
        return abs(odds) / (100 - odds)

# %%
american_to_percentage(-200)
# Out:
# 0.6666666666666666

# %%
def american_to_probability_average(odds, opp_odds):
    odds_pct = american_to_probability(odds)
    opp_odds_pct = american_to_probability(opp_odds)
    return (odds_pct) / (odds_pct + opp_odds_pct)

# %%
american_to_probability_average(-137, 120)
# Out:
# 0.5598068350668648

# %%
def profit_from_win(odds, bet=100):
    if odds > 0:
        return (odds / 100) * bet
    else:
        return 100 * (bet / abs(odds))

# %%
profit_from_win(200)
# Out:
# 200.0

# %%
# what proportion of your total should go to each side to minimize total loss?
# is it just bet size * probability of outcome? Yes
probability = american_to_probability_average(-136, 120)
total_bet = 100
bet_1 = total_bet * probability
bet_2 = total_bet * (1 - probability)
profit_if_1_wins = profit_from_win(-136, bet_1) + bet_1
profit_if_2_wins = profit_from_win(120, bet_2) + bet_2
print(profit_if_1_wins, profit_if_2_wins)
# Out:
# 97.01046337817638 97.01046337817638

# %%
def even_split_bet_amounts(odds_1, odds_2, total_bet=1):
    probability = american_to_probability_average(odds_1, odds_2)
    bet_1 = probability * total_bet
    bet_2 = (1 - probability) * total_bet
    return bet_1, bet_2

# %%
def even_split_bet_expected_return(odds_1, odds_2):
    bet_1, bet_2 = even_split_bet_amounts(odds_1, odds_2)
    profit_if_1_wins = profit_from_win(odds_1, bet_1) + bet_1
    profit_if_2_wins = profit_from_win(odds_2, bet_2) + bet_2
    assert abs(profit_if_1_wins - profit_if_2_wins) < 1e-6
    return profit_if_1_wins

# %%
even_split_bet_expected_return(-137, 120)
# Out:
# 0.9684249628528976
