# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = True
# - double_after_split = True
# - blackjack_pays = 1.5
#
# Discrepancies:
# -

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = True
# - double_after_split = True
# - blackjack_pays = 6/5
#
# Discrepancies:
# -

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = True
# - double_after_split = False
# - blackjack_pays = 1.5
#
# Discrepancies:
# -

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = True
# - double_after_split = False
# - blackjack_pays = 6/5
#
# Discrepancies:
# -

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = False
# - double_after_split = True
# - blackjack_pays = 1.5
#
# Discrepancies:
# -

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = False
# - double_after_split = True
# - blackjack_pays = 6/5
#
# Discrepancies:
# -

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = False
# - double_after_split = False
# - blackjack_pays = 1.5
#
# Discrepancies:
# -

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = False
# - double_after_split = False
# - blackjack_pays = 6/5
#
# Discrepancies:
# -
