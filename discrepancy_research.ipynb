# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = True
# - double_after_split = True
# - blackjack_pays = 1.5
#
# Discrepancies:
# - pla

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = True
# - double_after_split = True
# - blackjack_pays = 6/5
#
# Discrepancies:
# - player 5: mine says double on dealer 2,3,5,8,9,11, WOO says hit on all
# - player 6: mine says double on dealer 2,4,5,6,9,11, WOO says hit on all
# - player 7: mine says double on dealer 3-6, WOO says hit on all
# - player 8: mine says double on dealer 2,3,6,7,8, WOO says hit on all
# - player 9: mine says double on dealer 2 instead of hit, hit on dealer 3-5 instead of double
# - player 10: mine says double on dealer 10 or 11 instead of hit
# - player 11 through 20 are all perfect
# - paired 2s: mine says split instead of hit on dealer 7, mine says double instead of hit on dealer 10
# - paired 3s: mine says hit against a 2 instead of split, mine says split against a 7 instead of hit, mine says double against a 10 instead of hit
# - paired 4s: mine says double against a 2,7,8,9 instead of hit, double against a 5 instead of split
# - paired 5s: mine says double against a 10 or 11 instead of hit
# - paired 6s is perfect
# - paired 7s: mine says split against an 8 instead of hit
# - paired 8s is perfect
# - paired 9s: mine says split against an 11 instead of stand
# - paired 10s was omitted from mine all together???
# - paired aces is perfect
# - soft counts say to double way too often

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = True
# - double_after_split = False
# - blackjack_pays = 1.5
#
# Discrepancies:
# -

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = True
# - double_after_split = False
# - blackjack_pays = 6/5
#
# Discrepancies:
# -

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = False
# - double_after_split = True
# - blackjack_pays = 1.5
#
# Discrepancies:
# -

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = False
# - double_after_split = True
# - blackjack_pays = 6/5
#
# Discrepancies:
# -

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = False
# - double_after_split = False
# - blackjack_pays = 1.5
#
# Discrepancies:
# -

# %% [markdown]
# Scenario:
# - dealer_hit_soft_17 = False
# - double_after_split = False
# - blackjack_pays = 6/5
#
# Discrepancies:
# -
